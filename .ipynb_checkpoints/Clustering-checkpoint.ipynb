# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import OneHotEncoder, PolynomialFeatures
from sklearn import linear_model as lm
import sklearn.preprocessing as pre
from sklearn.metrics import mean_squared_error
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.metrics import make_scorer
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.utils import shuffle
from sklearn import svm

import bokeh.plotting as bp
from bokeh.models import HoverTool, BoxSelectTool
from bokeh.plotting import figure, show, output_notebook

from sklearn.svm import SVC

from IPython.display import display, Latex, Markdown

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('mrc_table5.csv')

# %%
columns = ['cohort', 'name', 'type', 'tier', 'tier_name', 'iclevel',
       'region', 'state', 'county', 'count_m', 'par_mean_m', 'par_rank_m', \
          'par_q1_m', 'par_q2_m', 'par_q3_m', 'par_q4_m', 'par_q5_m', 'par_top10pc_m', 'par_top5pc_m', \
          'par_top1pc_m', 'par_toppt1pc_m', 'k_q1_m', 'k_q2_m', 'k_q3_m', 'k_q4_m', 'k_q5_m', \
          'count_f', 'par_mean_f', 'par_rank_f', 'mr_kq5_pq1_age20', 'mr_kq5_pq1_m', 'mr_kq5_pq1_f', \
          'par_q1_f', 'par_q2_f', 'par_q3_f', 'par_q4_f', 'par_q5_f', 'par_top10pc_f', 'par_top5pc_f', \
          'par_top1pc_f', 'par_toppt1pc_f', 'k_q1_f', 'k_q2_f', 'k_q3_f', 'k_q4_f', 'k_q5_f']

columns_no_metrics = ['cohort', 'name', 'type', 'tier', 'tier_name', 'iclevel',
       'region', 'state', 'county', 'count_m', 'par_mean_m', 'par_rank_m', \
          'par_q1_m', 'par_q2_m', 'par_q3_m', 'par_q4_m', 'par_q5_m', 'par_top10pc_m', 'par_top5pc_m', \
          'par_top1pc_m', 'par_toppt1pc_m',\
          'count_f', 'par_mean_f', 'par_rank_f', 'mr_kq5_pq1_age20', 'mr_kq5_pq1_m', 'mr_kq5_pq1_f', \
          'par_q1_f', 'par_q2_f', 'par_q3_f', 'par_q4_f', 'par_q5_f', 'par_top10pc_f', 'par_top5pc_f', \
          'par_top1pc_f', 'par_toppt1pc_f']
data_1 = data[columns_no_metrics]

# %%
data_1 = data_1.dropna()

# %%
data_1['name'].unique()
# Out:
# array(['ASA Institute Of Business & Computer Technology',
#        'Abilene Christian University',
#        'Abraham Baldwin Agricultural College', ...,
#        'Youngstown State University', 'Yuba Community College District',
#        'Zane State College'], dtype=object)

# %%
pd.set_option('display.max_columns', None)
data_1[data_1['name'] == 'ASA Institute Of Business & Computer Technology']
# Out:
#     cohort                                             name  type  tier  \
# 3     1983  ASA Institute Of Business & Computer Technology   3.0    11
# 4     1984  ASA Institute Of Business & Computer Technology   3.0    11
# 5     1985  ASA Institute Of Business & Computer Technology   3.0    11
# 6     1986  ASA Institute Of Business & Computer Technology   3.0    11
# 7     1987  ASA Institute Of Business & Computer Technology   3.0    11
# 8     1988  ASA Institute Of Business & Computer Technology   3.0    11
# 9     1989  ASA Institute Of Business & Computer Technology   3.0    11
# 10    1990  ASA Institute Of Business & Computer Technology   3.0    11
# 11    1991  ASA Institute Of Business & Computer Technology   3.0    11
#
#               tier_name  iclevel  region state county  count_m    par_mean_m  \
# 3   Two-year for-profit      2.0     1.0    NY  Kings     52.0  33833.484375
# 4   Two-year for-profit      2.0     1.0    NY  Kings     78.0  33000.671875
# 5   Two-year for-profit      2.0     1.0    NY  Kings     90.0  36690.152344
# 6   Two-year for-profit      2.0     1.0    NY  Kings    137.0  31757.449219
# 7   Two-year for-profit      2.0     1.0    NY  Kings    177.0  26818.912109
# 8   Two-year for-profit      2.0     1.0    NY  Kings    277.0  31242.806641
# 9   Two-year for-profit      2.0     1.0    NY  Kings    354.0  34304.109375
# 10  Two-year for-profit      2.0     1.0    NY  Kings    403.0  32922.972656
# 11  Two-year for-profit      2.0     1.0    NY  Kings    410.0  31722.675781
#
#     par_rank_m  par_q1_m  par_q2_m  par_q3_m  par_q4_m  par_q5_m  \
# 3     0.267906  0.440599  0.366877  0.096647  0.058159  0.037718
# 4     0.278202  0.357310  0.410071  0.151134  0.051784  0.029701
# 5     0.288149  0.400925  0.366272  0.119568  0.102060  0.011176
# 6     0.287130  0.393942  0.304675  0.238520  0.059238  0.003624
# 7     0.253622  0.488005  0.314388  0.127398  0.058506  0.011703
# 8     0.278155  0.451601  0.276663  0.203774  0.053587  0.014375
# 9     0.289807  0.420615  0.280725  0.213839  0.066800  0.018022
# 10    0.290007  0.406884  0.333995  0.174615  0.067540  0.016966
# 11    0.309700  0.391366  0.303492  0.199013  0.072696  0.033432
#
#     par_top10pc_m  par_top5pc_m  par_top1pc_m  par_toppt1pc_m  count_f  \
# 3        0.000000      0.000000           0.0             0.0    197.0
# 4        0.000000      0.000000           0.0             0.0    294.0
# 5        0.002150      0.000251           0.0             0.0    321.0
# 6        0.001121      0.001121           0.0             0.0    341.0
# 7        0.004623      0.000000           0.0             0.0    463.0
# 8        0.007483      0.000000           0.0             0.0    501.0
# 9        0.001101      0.000000           0.0             0.0    600.0
# 10       0.003377      0.002447           0.0             0.0    578.0
# 11       0.007406      0.000000           0.0             0.0    544.0
#
#       par_mean_f  par_rank_f  mr_kq5_pq1_age20  mr_kq5_pq1_m  mr_kq5_pq1_f  \
# 3   34889.710938    0.267968          0.007857      0.017870      0.005117
# 4   29195.226562    0.235297          0.027361      0.000000      0.030478
# 5   35303.429688    0.265607          0.035296      0.066489      0.024722
# 6   28973.449219    0.242707          0.016041      0.043601      0.017546
# 7   29226.462891    0.243967          0.054742      0.023232      0.034620
# 8   28394.917969    0.254954          0.026180      0.028671      0.011956
# 9   30951.089844    0.270174          0.021121      0.039169      0.013709
# 10  27540.912109    0.258380          0.027972      0.029637      0.024227
# 11  30325.076172    0.284898          0.061365      0.041862      0.052584
#
#     par_q1_f  par_q2_f  par_q3_f  par_q4_f  par_q5_f  par_top10pc_f  \
# 3   0.455193  0.260613  0.192258  0.075756  0.016180       0.014387
# 4   0.493255  0.344769  0.106721  0.035013  0.020243       0.000000
# 5   0.441038  0.321158  0.162599  0.044123  0.031082       0.002081
# 6   0.474747  0.353473  0.114687  0.041707  0.015386       0.002375
# 7   0.486835  0.293701  0.176065  0.035263  0.008135       0.001902
# 8   0.457611  0.322456  0.157583  0.052045  0.010305       0.001175
# 9   0.447270  0.304699  0.172037  0.062931  0.013062       0.004524
# 10  0.478594  0.305234  0.150658  0.050082  0.015433       0.008541
# 11  0.408202  0.307282  0.211042  0.063238  0.010236       0.002371
#
#     par_top5pc_f  par_top1pc_f  par_toppt1pc_f
# 3       0.010109      0.000000        0.000000
# 4       0.000000      0.000000        0.000000
# 5       0.002081      0.002081        0.000099
# 6       0.001351      0.000363        0.000000
# 7       0.000000      0.000000        0.000000
# 8       0.000374      0.000072        0.000000
# 9       0.004175      0.000000        0.000000
# 10      0.002282      0.000068        0.000067
# 11      0.002371      0.001434        0.000042

# %%
cols_to_group = ['name', 'type', 'tier', 'tier_name', 'iclevel', 'region', 'state', 'county']
cols_to_ave = ['count_m', 'par_mean_m', 'par_rank_m','par_q1_m', 'par_q2_m', 'par_q3_m', 'par_q4_m', 'par_q5_m', 'par_top10pc_m', 'par_top5pc_m', \
               'par_top1pc_m', 'par_toppt1pc_m', 'k_q1_m', 'k_q2_m', 'k_q3_m', 'k_q4_m', 'k_q5_m','count_f', 'par_mean_f', 'par_rank_f', \
               'par_q1_f', 'par_q2_f', 'par_q3_f', 'par_q4_f', 'par_q5_f', 'par_top10pc_f', 'par_top5pc_f', \
               'par_top1pc_f', 'par_toppt1pc_f', 'k_q1_f', 'k_q2_f', 'k_q3_f', 'k_q4_f', 'k_q5_f', \
              'mr_kq5_pq1_age20', 'mr_kq5_pq1_m', 'mr_kq5_pq1_f']
cols_to_ave_no_metrics = ['count_m', 'par_mean_m', 'par_rank_m','par_q1_m', 'par_q2_m', 'par_q3_m', 'par_q4_m', 'par_q5_m', 'par_top10pc_m', 'par_top5pc_m', \
               'par_top1pc_m', 'par_toppt1pc_m','count_f', 'par_mean_f', 'par_rank_f', \
               'par_q1_f', 'par_q2_f', 'par_q3_f', 'par_q4_f', 'par_q5_f', 'par_top10pc_f', 'par_top5pc_f', \
               'par_top1pc_f', 'par_toppt1pc_f', \
              'mr_kq5_pq1_age20', 'mr_kq5_pq1_m', 'mr_kq5_pq1_f']
uni_data = data_1.groupby(cols_to_group, as_index = False)[cols_to_ave_no_metrics].mean()

# uni_data has columns that dont make a lot of sense but since the same transformation has been
# applied to all the data points it shouldnt matter for similarity

# %%
uni_data.head(2)
# Out:
#                                               name  type  tier  \
# 0  ASA Institute Of Business & Computer Technology   3.0    11
# 1                     Abilene Christian University   2.0     6
#
#              tier_name  iclevel  region state  county     count_m  \
# 0  Two-year for-profit      2.0     1.0    NY   Kings  219.777778
# 1    Selective private      1.0     3.0    TX  Taylor  364.500000
#
#       par_mean_m  par_rank_m  par_q1_m  par_q2_m  par_q3_m  par_q4_m  \
# 0   32477.026042    0.282520  0.416805  0.328573  0.169390  0.065597
# 1  167309.361979    0.704246  0.047610  0.089820  0.152779  0.247925
#
#    par_q5_m  par_top10pc_m  par_top5pc_m  par_top1pc_m  par_toppt1pc_m  \
# 0  0.019635       0.003029      0.000424      0.000000        0.000000
# 1  0.461865       0.272828      0.148296      0.026485        0.002128
#
#       count_f     par_mean_f  par_rank_f  par_q1_f  par_q2_f  par_q3_f  \
# 0  426.555556   30533.363932    0.258217  0.460305  0.312598  0.160406
# 1  449.166667  152498.831380    0.699332  0.048469  0.086129  0.156709
#
#    par_q4_f  par_q5_f  par_top10pc_f  par_top5pc_f  par_top1pc_f  \
# 0  0.051128  0.015562       0.004151      0.002527      0.000446
# 1  0.260350  0.448343       0.252298      0.135608      0.023491
#
#    par_toppt1pc_f  mr_kq5_pq1_age20  mr_kq5_pq1_m  mr_kq5_pq1_f
# 0        0.000023          0.030882      0.032281      0.023884
# 1        0.001473          0.011888      0.015753      0.008965

# %%
# pre processing

uni_data_1 = uni_data.copy()
#uni_data_1 = uni_data_1.drop('tier_name',1)
mobility = uni_data_1[['name', 'mr_kq5_pq1_age20', 'mr_kq5_pq1_m', 'mr_kq5_pq1_f']]
uni_data_1 = uni_data_1.drop(['name', 'mr_kq5_pq1_age20', 'mr_kq5_pq1_m', 'mr_kq5_pq1_f'],1)

# %%
# add extra features
'''
qs_m = []
for i, row in uni_data_1.iterrows():
    quantile = np.argmax(uni_data_1[['k_q1_m', 'k_q2_m', 'k_q3_m', 'k_q4_m', 'k_q5_m']].loc[i].values) + 1
    qs_m.append(quantile)

qs_f = []
for i, row in uni_data_1.iterrows():
    quantile = np.argmax(uni_data_1[['k_q1_f', 'k_q2_f', 'k_q3_f', 'k_q4_f', 'k_q5_f']].loc[i].values) + 1
    qs_f.append(quantile)

uni_data_1['label_m'] = qs_m
uni_data_1['label_f'] = qs_f
'''
# Out:
# "\nqs_m = []\nfor i, row in uni_data_1.iterrows():\n    quantile = np.argmax(uni_data_1[['k_q1_m', 'k_q2_m', 'k_q3_m', 'k_q4_m', 'k_q5_m']].loc[i].values) + 1\n    qs_m.append(quantile)\n\nqs_f = []\nfor i, row in uni_data_1.iterrows():\n    quantile = np.argmax(uni_data_1[['k_q1_f', 'k_q2_f', 'k_q3_f', 'k_q4_f', 'k_q5_f']].loc[i].values) + 1\n    qs_f.append(quantile)\n\nuni_data_1['label_m'] = qs_m\nuni_data_1['label_f'] = qs_f\n"

# %%
uni_data_2 = pd.get_dummies(uni_data_1)

# %%
from sklearn.preprocessing import scale
for c in uni_data_2.columns:
    uni_data_2[c] = scale(uni_data_2[c].values)

# %%
uni_data_2.shape, uni_data_1.shape
# Out:
# ((2262, 910), (2262, 31))

# %% [markdown]
# ## Kmeans

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(init='k-means++',n_clusters=20, random_state=0).fit(uni_data_2)

# %%
mobility['cluster_n'] = kmeans.labels_
centers = kmeans.cluster_centers_
distances = kmeans.transform(uni_data_2)

# %%
from sklearn.manifold import TSNE

tsne_model = TSNE(n_components=2, random_state=0)
tsne_kmeans = tsne_model.fit_transform(distances)
kmeans_centers = kmeans.predict(uni_data_2)

colormap = np.array(["#6d8dca", "#69de53", "#723bca", "#c3e14c", "#c84dc9", "#68af4e", "#6e6cd5",
"#e3be38", "#4e2d7c", "#5fdfa8", "#d34690", "#3f6d31", "#d44427", "#7fcdd8", "#cb4053", "#5e9981",
"#803a62", "#9b9e39", "#c88cca", "#e1c37b", "#34223b", "#bdd8a3", "#6e3326", "#cfbdce", "#d07d3c",
"#52697d", "#7d6d33", "#d27c88", "#36422b", "#b68f79"])

plot_kmeans = bp.figure(plot_width=700, plot_height=600, title="KMeans clustering of the colleges",
    x_axis_type=None, y_axis_type=None, min_border=1)

k_df = pd.DataFrame(tsne_kmeans, columns=['x', 'y'])
k_df['cluster'] = kmeans_centers
plot_kmeans.scatter(x=k_df['x'], y=k_df['y'], 
                    color=colormap[kmeans_centers])
show(plot_kmeans)

# %% [markdown]
# ## PCA

# %% [markdown]
# The first component explains nearly all the variance!
#
# The most relevant features of the 1st Principal Component are 'count_m/f' and 'par_mean_m/f'.

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=20).fit(uni_data_2)
components = pca.transform(uni_data_2)
best_features = np.where(abs(pca.components_[0]) >0.2)[0]
print([uni_data_2.iloc[:, [k]].columns[0] for k in best_features])
print(pca.explained_variance_ratio_)
# Out:
# ['par_mean_m', 'par_rank_m', 'par_q5_m', 'par_top10pc_m', 'par_top5pc_m', 'par_top1pc_m', 'par_mean_f', 'par_rank_f', 'par_q2_f', 'par_q5_f', 'par_top10pc_f', 'par_top5pc_f', 'par_top1pc_f']
# [ 0.01924965  0.00647669  0.00373564  0.0031557   0.00294961  0.00274779
#   0.00238451  0.00234484  0.00222804  0.0022036   0.00219667  0.00219006
#   0.0021741   0.00216423  0.0021513   0.00214994  0.00213979  0.00213632
#   0.00212138  0.00211503]

# %%
# using pcs to cluster with Kmeans
kmeans = KMeans(init=pca.components_ ,n_clusters=10, random_state=0).fit(uni_data_2)
mobility['cluster_n'] = kmeans.labels_
centers = kmeans.cluster_centers_
distances = kmeans.transform(uni_data_2)
from sklearn.manifold import TSNE

tsne_model = TSNE(n_components=2, random_state=0)
tsne_kmeans = tsne_model.fit_transform(distances)
kmeans_centers = kmeans.predict(uni_data_2)

colormap = np.array(["#6d8dca", "#69de53", "#723bca", "#c3e14c", "#c84dc9", "#68af4e", "#6e6cd5",
"#e3be38", "#4e2d7c", "#5fdfa8", "#d34690", "#3f6d31", "#d44427", "#7fcdd8", "#cb4053", "#5e9981",
"#803a62", "#9b9e39", "#c88cca", "#e1c37b", "#34223b", "#bdd8a3", "#6e3326", "#cfbdce", "#d07d3c",
"#52697d", "#7d6d33", "#d27c88", "#36422b", "#b68f79"])

plot_kmeans = bp.figure(plot_width=700, plot_height=600, title="KMeans clustering of the colleges",
    x_axis_type=None, y_axis_type=None, min_border=1)

k_df = pd.DataFrame(tsne_kmeans, columns=['x', 'y'])
k_df['cluster'] = kmeans_centers
plot_kmeans.scatter(x=k_df['x'], y=k_df['y'], 
                    color=colormap[kmeans_centers])
show(plot_kmeans)

# %%
clusters = (mobility
 .groupby('cluster_n')[['mr_kq5_pq1_age20', 'mr_kq5_pq1_m', 'mr_kq5_pq1_f']]
 .mean()
 .sort_values(by='mr_kq5_pq1_age20', ascending=False)
 )

# %%
clusters
# Out:
#            mr_kq5_pq1_age20  mr_kq5_pq1_m  mr_kq5_pq1_f
# cluster_n
# 17                 0.029723      0.033090      0.025756
# 13                 0.026646      0.033753      0.015527
# 0                  0.025957      0.033373      0.019883
# 10                 0.025780      0.033191      0.020069
# 11                 0.023471      0.034498      0.013992
# 1                  0.023285      0.023612      0.023004
# 3                  0.022414      0.029313      0.015353
# 4                  0.022231      0.021654      0.020557
# 14                 0.021359      0.020654      0.019392
# 7                  0.016612      0.019576      0.011703
# 2                  0.016401      0.020666      0.010967
# 5                  0.016377      0.023510      0.014055
# 6                  0.015813      0.017716      0.013734
# 8                  0.015652      0.019099      0.012079
# 18                 0.015364      0.019804      0.011551
# 16                 0.015160      0.020455      0.008295
# 9                  0.014323      0.022165      0.009234
# 12                 0.014201      0.013541      0.014662
# 15                 0.013211      0.016682      0.009971
# 19                 0.011257      0.013260      0.009608

# %%
clusters_name = (mobility
                .groupby('cluster_n')['name']
                .apply(lambda x: ', '.join(x))
                 )
clustersname = pd.DataFrame()
clustersname['name'] = clusters_name.values

# %%
clustersname
# Out:
#                                                  name
# 0   American Career College of Ontario, CA, Argosy...
# 1   Bethune Cookman University, Daytona State Coll...
# 2   Fortis College of Cuyahoga Falls, OH, Universi...
# 3   ASA Institute Of Business & Computer Technolog...
# 4   Academy Of Art University, California College ...
# 5   Brigham Young University - Hawaii, Chaminade U...
# 6   Abilene Christian University, Adams State Univ...
# 7      Averett University, Danville Community College
# 8   Art Institute Of Seattle , Bates Technical Col...
# 9   Albion College, Jacksonville State University,...
# 10  Florida Atlantic University, Fortis Institute ...
# 11                    East Arkansas Community College
# 12  Amherst College, Babson College, Bard College,...
# 13                      Lake Area Technical Institute
# 14  American University , Catholic University Of A...
# 15  American Institute Of Business, Briar Cliff Un...
# 16  Friends University, Newman University, Wichita...
# 17  Delgado Community College, Dillard University,...
# 18  Chowan University, Roanoke Chowan Community Co...
# 19                             University Of Montana

# %%
full_clusters = (clusters.merge(clustersname, on=None, left_index=True, right_index=True)
                 .sort_values(by = 'mr_kq5_pq1_age20', ascending = False)
                 )

# %%
full_clusters
# Out:
#     mr_kq5_pq1_age20  mr_kq5_pq1_m  mr_kq5_pq1_f  \
# 17          0.029723      0.033090      0.025756
# 13          0.026646      0.033753      0.015527
# 0           0.025957      0.033373      0.019883
# 10          0.025780      0.033191      0.020069
# 11          0.023471      0.034498      0.013992
# 1           0.023285      0.023612      0.023004
# 3           0.022414      0.029313      0.015353
# 4           0.022231      0.021654      0.020557
# 14          0.021359      0.020654      0.019392
# 7           0.016612      0.019576      0.011703
# 2           0.016401      0.020666      0.010967
# 5           0.016377      0.023510      0.014055
# 6           0.015813      0.017716      0.013734
# 8           0.015652      0.019099      0.012079
# 18          0.015364      0.019804      0.011551
# 16          0.015160      0.020455      0.008295
# 9           0.014323      0.022165      0.009234
# 12          0.014201      0.013541      0.014662
# 15          0.013211      0.016682      0.009971
# 19          0.011257      0.013260      0.009608
#
#                                                  name
# 17  Delgado Community College, Dillard University,...
# 13                      Lake Area Technical Institute
# 0   American Career College of Ontario, CA, Argosy...
# 10  Florida Atlantic University, Fortis Institute ...
# 11                    East Arkansas Community College
# 1   Bethune Cookman University, Daytona State Coll...
# 3   ASA Institute Of Business & Computer Technolog...
# 4   Academy Of Art University, California College ...
# 14  American University , Catholic University Of A...
# 7      Averett University, Danville Community College
# 2   Fortis College of Cuyahoga Falls, OH, Universi...
# 5   Brigham Young University - Hawaii, Chaminade U...
# 6   Abilene Christian University, Adams State Univ...
# 8   Art Institute Of Seattle , Bates Technical Col...
# 18  Chowan University, Roanoke Chowan Community Co...
# 16  Friends University, Newman University, Wichita...
# 9   Albion College, Jacksonville State University,...
# 12  Amherst College, Babson College, Bard College,...
# 15  American Institute Of Business, Briar Cliff Un...
# 19                             University Of Montana

# %%
mobility.sort_values(by = 'mr_kq5_pq1_age20', ascending = False).head(20)
# Out:
#                                                    name  mr_kq5_pq1_age20  \
# 224                      CUNY Bernard M. Baruch College          0.119430
# 231                                 CUNY Lehman College          0.089314
# 360                     City College Of New York - CUNY          0.088708
# 1858                 Texas A&M International University          0.085492
# 2061                 University Of Texas - Pan American          0.079212
# 1292  New York City College Of Technology Of The Cit...          0.077538
# 229           CUNY John Jay College Of Criminal Justice          0.077052
# 2190           Western Technical College of El Paso, TX          0.071704
# 259            California State University, Los Angeles          0.069605
# 1842                        Technical Career Institutes          0.067491
# 1719                                South Texas College          0.067206
# 2064                 University Of Texas At Brownsville          0.065629
# 227                               CUNY Brooklyn College          0.064564
# 1808        State University Of New York At Stony Brook          0.063963
# 228                                 CUNY Hunter College          0.063624
# 141                    Berkeley College of New York, NY          0.063024
# 2066                     University Of Texas At El Paso          0.062645
# 771                      Hallmark College Of Technology          0.061577
# 226                        CUNY Bronx Community College          0.060970
# 1009                           Laredo Community College          0.060599
#
#       mr_kq5_pq1_m  mr_kq5_pq1_f  cluster_n
# 224       0.109670      0.119192          3
# 231       0.106383      0.080538          3
# 360       0.098475      0.074076          3
# 1858      0.098949      0.069869          3
# 2061      0.091812      0.063163          3
# 1292      0.084646      0.055131          3
# 229       0.087077      0.065195          3
# 2190      0.104796      0.016932          3
# 259       0.080212      0.059156          3
# 1842      0.066284      0.028452          3
# 1719      0.104264      0.031278          3
# 2064      0.088156      0.041534          3
# 227       0.065420      0.058813          3
# 1808      0.064760      0.062052          6
# 228       0.060915      0.063420          3
# 141       0.068325      0.050982          3
# 2066      0.068862      0.049884          3
# 771       0.050522      0.056336          3
# 226       0.073065      0.045102          3
# 1009      0.094948      0.029298          3

# %%
def dist_cluster(cluster, df, mob):
    cluster_nms = df.loc[cluster, 'name'].split(', ')
    in_ = [name in cluster_nms for name in mobility['name']]
    mobilities_ = mobility[in_][mob]
    return mobilities_

# %%
f, axs = plt.subplots(4,5)
axs = axs.ravel()
f.subplots_adjust(hspace=.9)
f.subplots_adjust(wspace=.8)
for i in range(centers.shape[0]):
    v = dist_cluster(i, full_clusters, 'mr_kq5_pq1_age20')
    axs[i].hist(v, bins=50)
    title = 'Cluster ' + str(i)
    axs[i].set_title(title)
    rang = np.round_(np.linspace(min(v), max(v), 3), 2)
    axs[i].set_xticks(rang)
plt.show()

# %%
# analyze CUNY Bernard M. Baruch College cluster 

mobility_6 = dist_cluster(3, full_clusters, 'mr_kq5_pq1_age20')
mobility_6.hist(bins=50)

# %%
# analyze CUNY Bernard M. Baruch College cluster number 6, with logs

mobility_6 = np.log(dist_cluster(3, full_clusters, 'mr_kq5_pq1_age20'))
mobility_6.hist(bins=50)

# %%
def important_features(names, n_important):
    '''
        input: list of college names
        output: dictionary with features and point values
        
        This function finds the 5 features that increase the euclidean distance of each college from the 
        closest cluster center the most and and builds a dictionary where these features are the keys and the 
        values are a sum of the pts obtained by each feature.
        Each time a feature is ranked i in 1 to 5 it gets 5 - i points.
        At the end features with most points are the features that for each college make them the most different to
        the other colleges in the cluster.
    
    '''
    
    dic = {}
    for n in names:
        idx = uni_data_2[mobility['name'] == n].index[0]
        vect = uni_data_2.loc[idx,:]
        dists = pd.DataFrame([(vect[i]-centers[4,i])**2 for i in range(uni_data_2.shape[1])]).sort_values(by=0, ascending=False)
        best_five = dists.head(n_important).index
        for i in range(len(best_five)):
            feat = best_five[i]
            if feat not in dic.keys():
                dic[feat] = 0
            dic[feat] += n_important - i
    return dic

# %%
names= mobility.sort_values(by = 'mr_kq5_pq1_age20', ascending = False)['name'].head(300).values

# %%
fs = important_features(names, 8)

# %%
fs_n = {}
for k in fs.keys():
    fs_n[uni_data_2.iloc[:, [k]].columns[0]] = fs[k]

# %%
fs_n
# Out:
# {'count_f': 70,
#  'count_m': 84,
#  'county_Alameda': 21,
#  'county_Albany': 21,
#  'county_Allegheny': 7,
#  'county_Allen': 7,
#  'county_Arlington': 8,
#  'county_Baldwin': 8,
#  'county_Bedford': 8,
#  'county_Bee': 8,
#  'county_Bergen': 16,
#  'county_Bexar': 35,
#  'county_Brazoria': 8,
#  'county_Brevard': 8,
#  'county_Brewster': 8,
#  'county_Bronx': 42,
#  'county_Broome': 8,
#  'county_Broward': 21,
#  'county_Caddo': 8,
#  'county_Calcasieu': 8,
#  'county_Camden': 8,
#  'county_Cameron': 16,
#  'county_Chatham': 8,
#  'county_Chester': 8,
#  'county_Chesterfield': 8,
#  'county_Claiborne': 8,
#  'county_Clark': 6,
#  'county_Collier': 16,
#  'county_Conecuh': 8,
#  'county_Cook': 63,
#  'county_Copiah': 8,
#  'county_Cumberland': 7,
#  'county_Dallas': 7,
#  'county_Davidson': 14,
#  'county_DeKalb': 7,
#  'county_Delaware': 21,
#  'county_Desoto': 8,
#  'county_District Of Columbia': 13,
#  'county_Dougherty': 8,
#  'county_East Baton Rouge': 24,
#  'county_Eastland': 16,
#  'county_Ector': 16,
#  'county_El Paso': 35,
#  'county_Erie': 7,
#  'county_Escambia': 8,
#  'county_Essex': 35,
#  'county_Fairfield': 14,
#  'county_Fayette': 7,
#  'county_Fresno': 16,
#  'county_Fulton': 7,
#  'county_Galveston': 8,
#  'county_Genesee': 14,
#  'county_Grant': 8,
#  'county_Gregg': 8,
#  'county_Hampden': 14,
#  'county_Harris': 63,
#  'county_Hartford': 7,
#  'county_Hidalgo': 16,
#  'county_Hill': 8,
#  'county_Hinds': 8,
#  'county_Hudson': 32,
#  'county_Imperial': 8,
#  'county_Izard': 8,
#  'county_Jefferson': 28,
#  'county_Jones': 8,
#  'county_Kern': 16,
#  'county_King': 7,
#  'county_Kings': 42,
#  'county_Kleberg': 8,
#  'county_Lafayette': 8,
#  'county_Le Flore': 8,
#  'county_Lea': 8,
#  'county_Leon': 8,
#  'county_Lincoln': 8,
#  'county_Logan': 8,
#  'county_Los Angeles': 160,
#  'county_Macon': 8,
#  'county_Madison': 7,
#  'county_Maricopa': 14,
#  'county_Marion': 7,
#  'county_McLennan': 8,
#  'county_Middlesex': 20,
#  'county_Midland': 8,
#  'county_Monroe': 7,
#  'county_Montgomery': 28,
#  'county_Nassau': 35,
#  'county_Natchitoches': 8,
#  'county_New Haven': 7,
#  'county_New York': 84,
#  'county_Newton': 8,
#  'county_Nolan': 8,
#  'county_Norfolk': 14,
#  'county_Norfolk City': 8,
#  'county_Nueces': 8,
#  'county_Oklahoma': 7,
#  'county_Okmulgee': 8,
#  'county_Oneida': 8,
#  'county_Onondaga': 8,
#  'county_Orange': 35,
#  'county_Orleans': 21,
#  'county_Ouachita': 8,
#  'county_Palm Beach': 21,
#  'county_Panola': 8,
#  'county_Passaic': 16,
#  'county_Pearl River': 8,
#  'county_Philadelphia': 7,
#  'county_Pike': 8,
#  'county_Pittsburg': 8,
#  'county_Platte': 8,
#  'county_Pratt': 8,
#  'county_Prince Georges': 8,
#  'county_Providence': 7,
#  'county_Queens': 49,
#  'county_Rapides': 16,
#  'county_Rensselaer': 8,
#  'county_Richmond': 8,
#  'county_Richmond City': 8,
#  'county_Riverside': 21,
#  'county_Rockland': 8,
#  'county_Sacramento': 16,
#  'county_San Bernardino': 21,
#  'county_San Diego': 21,
#  'county_San Francisco': 2264,
#  'county_San Joaquin': 8,
#  'county_Santa Clara': 7,
#  'county_Saratoga': 8,
#  'county_Scurry': 8,
#  'county_Shelby': 14,
#  'county_Smith': 8,
#  'county_Stanislaus': 8,
#  'county_Stark': 8,
#  'county_Suffolk': 56,
#  'county_Sumter': 16,
#  'county_Talladega': 8,
#  'county_Tallapoosa': 8,
#  'county_Tarrant': 16,
#  'county_Taylor': 8,
#  'county_Tazewell': 8,
#  'county_Terrebonne': 8,
#  'county_Travis': 7,
#  'county_Tulare': 8,
#  'county_Union': 7,
#  'county_Uvalde': 8,
#  'county_Victoria': 8,
#  'county_Volusia': 8,
#  'county_Waller': 8,
#  'county_Ware': 8,
#  'county_Washington': 7,
#  'county_Wayne': 7,
#  'county_Webb': 16,
#  'county_Westchester': 21,
#  'county_Williams': 8,
#  'county_Yolo': 8,
#  'iclevel': 45,
#  'par_mean_f': 34,
#  'par_mean_m': 6,
#  'par_q1_f': 243,
#  'par_q1_m': 242,
#  'par_q2_f': 181,
#  'par_q2_m': 198,
#  'par_q3_f': 38,
#  'par_q3_m': 30,
#  'par_q4_f': 21,
#  'par_q4_m': 33,
#  'par_q5_f': 14,
#  'par_q5_m': 66,
#  'par_rank_f': 127,
#  'par_rank_m': 109,
#  'par_top10pc_f': 5,
#  'par_top10pc_m': 54,
#  'par_top1pc_f': 6,
#  'par_top1pc_m': 11,
#  'par_top5pc_f': 10,
#  'par_top5pc_m': 14,
#  'par_toppt1pc_f': 13,
#  'par_toppt1pc_m': 24,
#  'region': 373,
#  'state_AL': 72,
#  'state_AR': 12,
#  'state_AZ': 12,
#  'state_CA': 1134,
#  'state_CT': 24,
#  'state_DC': 13,
#  'state_FL': 78,
#  'state_GA': 42,
#  'state_IL': 52,
#  'state_IN': 5,
#  'state_KS': 6,
#  'state_LA': 96,
#  'state_MA': 69,
#  'state_MD': 12,
#  'state_ME': 6,
#  'state_MI': 10,
#  'state_MO': 6,
#  'state_MS': 48,
#  'state_MT': 6,
#  'state_ND': 12,
#  'state_NJ': 94,
#  'state_NM': 6,
#  'state_NV': 7,
#  'state_NY': 296,
#  'state_OH': 12,
#  'state_OK': 24,
#  'state_PA': 30,
#  'state_RI': 6,
#  'state_TN': 30,
#  'state_TX': 295,
#  'state_VA': 30,
#  'state_WA': 12,
#  'state_WV': 12,
#  'tier': 185,
#  'tier_name_Four-year for-profit': 118,
#  'tier_name_Highly selective private': 41,
#  'tier_name_Highly selective public': 36,
#  'tier_name_Ivy Plus': 7,
#  'tier_name_Less than two-year schools of any type': 57,
#  'tier_name_Nonselective four-year private not-for-profit': 137,
#  'tier_name_Nonselective four-year public': 63,
#  'tier_name_Other elite schools (public and private)': 24,
#  'tier_name_Selective private': 163,
#  'tier_name_Selective public': 257,
#  'tier_name_Two-year (public and private not-for-profit)': 182,
#  'tier_name_Two-year for-profit': 196,
#  'type': 263}

# %% [markdown]
# ### Preliminary Results
#
# 1. For 5 important features we get that the most important features are almost exclusively the parent mean income as well as the university tier
# 2. For 10 important features tier, type, parent mean income and count are still the most important, but many county dummies also appear to have influence.
#
# From this we conclude that the most important features regard the type of college and family background, but that if we consider a larger range of features region, specially county, becomes important! It is also worth to note that in tier the most important features are Two-year and Selective public and Selective private as well as ivy+.
#
# These results are consistent with the PCA of the data!

# %%
import operator

sorted_fs = sorted(fs_n.items(), key=operator.itemgetter(1))
final_features = pd.DataFrame()
final_features = final_features.from_dict(sorted_fs).sort_values(by=1, ascending=False)
final_features.columns = ['feature', 'score']

# %%
final_features
# Out:
#                                                feature  score
# 223                               county_San Francisco   2264
# 222                                           state_CA   1134
# 221                                             region    373
# 220                                           state_NY    296
# 219                                           state_TX    295
# 218                                               type    263
# 217                         tier_name_Selective public    257
# 216                                           par_q1_f    243
# 215                                           par_q1_m    242
# 214                                           par_q2_m    198
# 213                      tier_name_Two-year for-profit    196
# 212                                               tier    185
# 211  tier_name_Two-year (public and private not-for...    182
# 210                                           par_q2_f    181
# 209                        tier_name_Selective private    163
# 208                                 county_Los Angeles    160
# 207  tier_name_Nonselective four-year private not-f...    137
# 206                                         par_rank_f    127
# 205                     tier_name_Four-year for-profit    118
# 204                                         par_rank_m    109
# 203                                           state_LA     96
# 202                                           state_NJ     94
# 201                                            count_m     84
# 200                                    county_New York     84
# 199                                           state_FL     78
# 198                                           state_AL     72
# 197                                            count_f     70
# 196                                           state_MA     69
# 195                                           par_q5_m     66
# 194                                        county_Cook     63
# ..                                                 ...    ...
# 13                                        county_Wayne      7
# 15                                    county_New Haven      7
# 14                                     county_Oklahoma      7
# 12                                        county_Union      7
# 11                                       county_Marion      7
# 22                                    county_Allegheny      7
# 21                                      county_Fayette      7
# 27                                  tier_name_Ivy Plus      7
# 23                                         county_Erie      7
# 30                                   county_Cumberland      7
# 24                                       county_Fulton      7
# 33                                       county_Monroe      7
# 32                                       county_Travis      7
# 31                                         county_King      7
# 34                                  county_Santa Clara      7
# 29                                   county_Providence      7
# 28                                       county_DeKalb      7
# 26                                      county_Madison      7
# 25                                        county_Allen      7
# 2                                             state_MO      6
# 10                                            state_MT      6
# 9                                             state_NM      6
# 8                                           par_mean_m      6
# 7                                         county_Clark      6
# 6                                             state_ME      6
# 5                                             state_RI      6
# 4                                             state_KS      6
# 3                                         par_top1pc_f      6
# 1                                             state_IN      5
# 0                                        par_top10pc_f      5
#
# [224 rows x 2 columns]
